# %%
from IPython.display import Image

# %% [markdown]
# # Part 1
# ## Check if the installation is complete:
# > - https://drive.google.com/drive/folders/1LIcdUBAYsaiqHLnvZ67GQobURpTKsEvH?usp=sharing
#
# #### Things that should be functional:
# > - Python Installation
# > - Virtual Environment
# > - Jupyter Notebook
# > - Packages
# > - Twitter Developer App
# > - Gephi
#
# <b>A walk throgh the installaiton procedure and what does all the things meant<b>
# _______

# %% [markdown]
# # Part 2
# > - Using Twitter API Keys

# %% [markdown]
# ### Introduction to Twitter
#
# #### What is Twitter?
# Twitter is a micro-blogging social network website, where users post 280 (previously 140) characters long messages called 'Tweets'.
#
# Link : https://twitter.com/
# ___

# %%
Image(filename='images/Twitter_image.png')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-2-28dcc6f644e0> in <module>()
# ----> 1 Image(filename='images/Twitter_image.png')
#
# ~/anaconda3/lib/python3.6/site-packages/IPython/core/display.py in __init__(self, data, url, filename, format, embed, width, height, retina, unconfined, metadata)
#    1149         self.unconfined = unconfined
#    1150         super(Image, self).__init__(data=data, url=url, filename=filename,
# -> 1151                 metadata=metadata)
#    1152
#    1153         if self.width is None and self.metadata.get('width', {}):
#
# ~/anaconda3/lib/python3.6/site-packages/IPython/core/display.py in __init__(self, data, url, filename, metadata)
#     607             self.metadata = {}
#     608
# --> 609         self.reload()
#     610         self._check_data()
#     611
#
# ~/anaconda3/lib/python3.6/site-packages/IPython/core/display.py in reload(self)
#    1180         """Reload the raw data from file or URL."""
#    1181         if self.embed:
# -> 1182             super(Image,self).reload()
#    1183             if self.retina:
#    1184                 self._retina_shape()
#
# ~/anaconda3/lib/python3.6/site-packages/IPython/core/display.py in reload(self)
#     632         """Reload the raw data from file or URL."""
#     633         if self.filename is not None:
# --> 634             with open(self.filename, self._read_flags) as f:
#     635                 self.data = f.read()
#     636         elif self.url is not None:
#
# FileNotFoundError: [Errno 2] No such file or directory: 'images/Twitter_image.png'

# %% [markdown]
# #### User actions on Twitter
# > - Tweet -- Post a message with image/video and text within 240 characters on Twitter.
# > - Retweet -- Retweet or share a tweet made by another user within Twitter.
# > - Reply -- Post a message in respose to another user's tweet.
# > - Mentions -- Tag another user in his/her tweet or reply.
# > - Hashtag -- Another tag used to link to a topic or event.
# > - Follow -- Follow or subscribe to a user's tweets. A Follower is a user that follows, and the user that is being followed in followee.
# > - Search -- To search for tweets posted by other accounts based on a query.

# %% [markdown]
# #### Twitter API
# Twitter provides an application programming interface (API) [1]. The API allows us to interact with the social media in many ways, like get user tweets, message users, search for tweets etc.
#
# #### How does one use the API?
# To use the API to do any of the above mentioned actions, the user needs to create a Twitter Developer App and get the following keys:
#
# #### Customer Key
# > - Consumer Secret
# > - Access Token
# > - Access Token Secret
# > - These are necessary for the authentication process with the API.
#
# #### How can I collect data from the API?
# The API has various endpoints to perform various actions. We will primarily be focussing on Search and Streaming.
#
# #### API rate limits
# The Twitter API is rate limited in order to avoid the API hits hampering with the behaviour of the social network.
#
# #### Libraries used
# > - Tweepy
# > - jsonpickle

# %% [markdown]
# #### Import library and initiate the API

# %%
import tweepy
from pprint import pprint #for printing the Tweet in a format 
import jsonpickle #for creating a pickle file for storing the tweets
#for getting Stream of Data
from tweepy import Stream
from tweepy.streaming import StreamListenerd

# %%
#Consumer Key (API Key), Consumer Secret (API Secret)
auth = tweepy.OAuthHandler('Wgl4KJ4mMyrUsFJWwJSWvAZs0','ZN7WwT4ybjEMItMT1Hj82ok1gbZInBtw9F7YEE5ffZ1yZkHEZ0')
# Access Token, Access Token Secret
auth.set_access_token('1408028250-25kg0zMh4w6TXafaGfTZN5xX2UfpVsvvgQTZ0Eh','hyXIp1hMwSgIhQE4ZGGoJccuYm4WpIBCEN8YvxHKFCGpJ')

api = tweepy.API(auth)
if (not api):
    print("Authentication failed :(")
else:
    print("Authentication successfull!!! :D")
# Out:
# Authentication successfull!!! :D

# %% [markdown]
# ### Search API
#
# #### Search Parameters
# ___

# %%
query = 's8n'  # this is what we're searching for
en_lang = 'en' # this is used to specify the language of the tweets
popular_results = 'popular' # used to specifiy the order of tweet results. Accepted values: popular|recent|mixec
extended_mode = 'extended' # used to tell the API not to truncate the tweet

# %%
#Query the endpoint
search_results = api.search(q=query, lang=en_lang, result_type=popular_results, 
                            tweet_mode=extended_mode)

# %%
#Print the result
print_till = 10
counter = 0
for tweet in search_results:
    if counter < print_till:
        pprint(tweet._json)
        print('--------------------------------------------------------')
        counter += 1
# Out:
# {'contributors': None,
#  'coordinates': None,
#  'created_at': 'Wed Jan 16 00:39:07 +0000 2019',
#  'display_text_range': [0, 42],
#  'entities': {'hashtags': [],
#               'symbols': [],
#               'urls': [{'display_url': 'twitter.com/s8n/status/108…',
#                         'expanded_url': 'https://twitter.com/s8n/status/1084573360611299331',
#                         'indices': [43, 66],
#                         'url': 'https://t.co/siLLaegVnZ'}],
#               'user_mentions': []},
#  'favorite_count': 140,
#  'favorited': False,
#  'full_text': "Satan...how come you're not verified yet?? "
#               'https://t.co/siLLaegVnZ',
#  'geo': None,
#  'id': 1085335606555627521,
#  'id_str': '1085335606555627521',
#  'in_reply_to_screen_name': None,
#  'in_reply_to_status_id': None,
#  'in_reply_to_status_id_str': None,
#  'in_reply_to_user_id': None,
#  'in_reply_to_user_id_str': None,
#  'is_quote_status': True,
#  'lang': 'en',
#  'metadata': {'iso_language_code': 'en', 'result_type': 'popular'},
#  'place': None,
#  'possibly_sensitive': False,
#  'quoted_status': {'contributors': None,
#                    'coordinates': None,
#                    'created_at': 'Sun Jan 13 22:10:14 +0000 2019',
#                    'display_text_range': [0, 101],
#                    'entities': {'hashtags': [],
#                                 'symbols': [],
#                                 'urls': [],
#                                 'user_mentions': []},
#                    'favorite_count': 35283,
#                    'favorited': False,
#                    'full_text': 'People try blame me for their shitty actions '
#                                 'saying I tempted them\n'
#                                 '\n'
#                                 'No bitch, you’re just an asshole.',
#                    'geo': None,
#                    'id': 1084573360611299331,
#                    'id_str': '1084573360611299331',
#                    'in_reply_to_screen_name': None,
#                    'in_reply_to_status_id': None,
#                    'in_reply_to_status_id_str': None,
#                    'in_reply_to_user_id': None,
#                    'in_reply_to_user_id_str': None,
#                    'is_quote_status': False,
#                    'lang': 'en',
#                    'metadata': {'iso_language_code': 'en',
#                                 'result_type': 'popular'},
#                    'place': None,
#                    'retweet_count': 7409,
#                    'retweeted': False,
#                    'source': '<a href="http://twitter.com/download/iphone" '
#                              'rel="nofollow">Twitter for iPhone</a>',
#                    'truncated': False,
#                    'user': {'contributors_enabled': False,
#                             'created_at': 'Mon Feb 18 09:16:57 +0000 2008',
#                             'default_profile': False,
#                             'default_profile_image': False,
#                             'description': 'Not evil just misunderstood | '
#                                            'https://t.co/hmJcQBAXGh | '
#                                            'https://t.co/nruh9nGktk | '
#                                            'Snapchat: satans | Spam Acc: '
#                                            '@s8nspam',
#                             'entities': {'description': {'urls': [{'display_url': 'Instagram.com/s8n',
#                                                                    'expanded_url': 'http://Instagram.com/s8n',
#                                                                    'indices': [30,
#                                                                                53],
#                                                                    'url': 'https://t.co/hmJcQBAXGh'},
#                                                                   {'display_url': 's8n.tumblr.com',
#                                                                    'expanded_url': 'http://s8n.tumblr.com',
#                                                                    'indices': [56,
#                                                                                79],
#                                                                    'url': 'https://t.co/nruh9nGktk'}]},
#                                          'url': {'urls': [{'display_url': 's8n.co',
#                                                            'expanded_url': 'http://s8n.co',
#                                                            'indices': [0, 23],
#                                                            'url': 'https://t.co/SApjh0eykv'}]}},
#                             'favourites_count': 13206,
#                             'follow_request_sent': False,
#                             'followers_count': 764680,
#                             'following': False,
#                             'friends_count': 51,
#                             'geo_enabled': False,
#                             'has_extended_profile': True,
#                             'id': 13615722,
#                             'id_str': '13615722',
#                             'is_translation_enabled': False,
#                             'is_translator': False,
#                             'lang': 'en',
#                             'listed_count': 1696,
#                             'location': 'hell',
#                             'name': 'Satan',
#                             'notifications': False,
#                             'profile_background_color': '000000',
#                             'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#                             'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#                             'profile_background_tile': False,
#                             'profile_banner_url': 'https://pbs.twimg.com/profile_banners/13615722/1455479554',
#                             'profile_image_url': 'http://pbs.twimg.com/profile_images/738139405446062081/x0FQk9Yl_normal.jpg',
#                             'profile_image_url_https': 'https://pbs.twimg.com/profile_images/738139405446062081/x0FQk9Yl_normal.jpg',
#                             'profile_link_color': 'FF0000',
#                             'profile_sidebar_border_color': '000000',
#                             'profile_sidebar_fill_color': 'DDEEF6',
#                             'profile_text_color': '333333',
#                             'profile_use_background_image': True,
#                             'protected': False,
#                             'screen_name': 's8n',
#                             'statuses_count': 2664,
#                             'time_zone': None,
#                             'translator_type': 'none',
#                             'url': 'https://t.co/SApjh0eykv',
#                             'utc_offset': None,
#                             'verified': False}},
#  'quoted_status_id': 1084573360611299331,
#  'quoted_status_id_str': '1084573360611299331',
#  'retweet_count': 10,
#  'retweeted': False,
#  'source': '<a href="http://twitter.com/download/android" '
#            'rel="nofollow">Twitter for Android</a>',
#  'truncated': False,
#  'user': {'contributors_enabled': False,
#           'created_at': 'Tue Mar 03 05:17:11 +0000 2009',
#           'default_profile': False,
#           'default_profile_image': False,
#           'description': 'Human Being. Actor. Paranormal Enthusiast. I love '
#                          'Candy & I cuss rather significantly.',
#           'entities': {'description': {'urls': []},
#                        'url': {'urls': [{'display_url': 'chadsjoint.com',
#                                          'expanded_url': 'https://www.chadsjoint.com/',
#                                          'indices': [0, 23],
#                                          'url': 'https://t.co/AVihhsK2gR'}]}},
#           'favourites_count': 12302,
#           'follow_request_sent': False,
#           'followers_count': 91335,
#           'following': False,
#           'friends_count': 971,
#           'geo_enabled': False,
#           'has_extended_profile': True,
#           'id': 22589633,
#           'id_str': '22589633',
#           'is_translation_enabled': False,
#           'is_translator': False,
#           'lang': 'en',
#           'listed_count': 1983,
#           'location': 'In a Galaxy far far away...',
#           'name': 'ChadLindberg',
#           'notifications': False,
#           'profile_background_color': '131516',
#           'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme14/bg.gif',
#           'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme14/bg.gif',
#           'profile_background_tile': False,
#           'profile_banner_url': 'https://pbs.twimg.com/profile_banners/22589633/1543643498',
#           'profile_image_url': 'http://pbs.twimg.com/profile_images/1080684708168589312/RxOzgmbo_normal.jpg',
#           'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1080684708168589312/RxOzgmbo_normal.jpg',
#           'profile_link_color': '1B95E0',
#           'profile_sidebar_border_color': 'FFFFFF',
#           'profile_sidebar_fill_color': 'EFEFEF',
#           'profile_text_color': '333333',
#           'profile_use_background_image': True,
#           'protected': False,
#           'screen_name': 'ChadLindberg',
#           'statuses_count': 65873,
#           'time_zone': None,
#           'translator_type': 'none',
#           'url': 'https://t.co/AVihhsK2gR',
#           'utc_offset': None,
#           'verified': True}}
# --------------------------------------------------------
# {'contributors': None,
#  'coordinates': None,
#  'created_at': 'Thu Jan 10 21:34:17 +0000 2019',
#  'display_text_range': [0, 37],
#  'entities': {'hashtags': [],
#               'symbols': [],
#               'urls': [{'display_url': 'twitter.com/s8n/status/108…',
#                         'expanded_url': 'https://twitter.com/s8n/status/1083439025065742341',
#                         'indices': [38, 61],
#                         'url': 'https://t.co/kDoqYezJoH'}],
#               'user_mentions': []},
#  'favorite_count': 5528,
#  'favorited': False,
#  'full_text': 'Satan has spoken! And it’s the Truth. https://t.co/kDoqYezJoH',
#  'geo': None,
#  'id': 1083477149171019776,
#  'id_str': '1083477149171019776',
#  'in_reply_to_screen_name': None,
#  'in_reply_to_status_id': None,
#  'in_reply_to_status_id_str': None,
#  'in_reply_to_user_id': None,
#  'in_reply_to_user_id_str': None,
#  'is_quote_status': True,
#  'lang': 'en',
#  'metadata': {'iso_language_code': 'en', 'result_type': 'popular'},
#  'place': None,
#  'possibly_sensitive': False,
#  'quoted_status': {'contributors': None,
#                    'coordinates': None,
#                    'created_at': 'Thu Jan 10 19:02:47 +0000 2019',
#                    'display_text_range': [0, 145],
#                    'entities': {'hashtags': [],
#                                 'symbols': [],
#                                 'urls': [],
#                                 'user_mentions': []},
#                    'favorite_count': 43383,
#                    'favorited': False,
#                    'full_text': 'For anyone who needs to see this... at the '
#                                 'end of the day, nobody really cares but '
#                                 'yourself. So just do what makes you happy. '
#                                 'Fuck everyone else.',
#                    'geo': None,
#                    'id': 1083439025065742341,
#                    'id_str': '1083439025065742341',
#                    'in_reply_to_screen_name': None,
#                    'in_reply_to_status_id': None,
#                    'in_reply_to_status_id_str': None,
#                    'in_reply_to_user_id': None,
#                    'in_reply_to_user_id_str': None,
#                    'is_quote_status': False,
#                    'lang': 'en',
#                    'metadata': {'iso_language_code': 'en',
#                                 'result_type': 'popular'},
#                    'place': None,
#                    'retweet_count': 14032,
#                    'retweeted': False,
#                    'source': '<a href="http://twitter.com/download/iphone" '
#                              'rel="nofollow">Twitter for iPhone</a>',
#                    'truncated': False,
#                    'user': {'contributors_enabled': False,
#                             'created_at': 'Mon Feb 18 09:16:57 +0000 2008',
#                             'default_profile': False,
#                             'default_profile_image': False,
#                             'description': 'Not evil just misunderstood | '
#                                            'https://t.co/hmJcQBAXGh | '
#                                            'https://t.co/nruh9nGktk | '
#                                            'Snapchat: satans | Spam Acc: '
#                                            '@s8nspam',
#                             'entities': {'description': {'urls': [{'display_url': 'Instagram.com/s8n',
#                                                                    'expanded_url': 'http://Instagram.com/s8n',
#                                                                    'indices': [30,
#                                                                                53],
#                                                                    'url': 'https://t.co/hmJcQBAXGh'},
#                                                                   {'display_url': 's8n.tumblr.com',
#                                                                    'expanded_url': 'http://s8n.tumblr.com',
#                                                                    'indices': [56,
#                                                                                79],
#                                                                    'url': 'https://t.co/nruh9nGktk'}]},
#                                          'url': {'urls': [{'display_url': 's8n.co',
#                                                            'expanded_url': 'http://s8n.co',
#                                                            'indices': [0, 23],
#                                                            'url': 'https://t.co/SApjh0eykv'}]}},
#                             'favourites_count': 13206,
#                             'follow_request_sent': False,
#                             'followers_count': 764680,
#                             'following': False,
#                             'friends_count': 51,
#                             'geo_enabled': False,
#                             'has_extended_profile': True,
#                             'id': 13615722,
#                             'id_str': '13615722',
#                             'is_translation_enabled': False,
#                             'is_translator': False,
#                             'lang': 'en',
#                             'listed_count': 1696,
#                             'location': 'hell',
#                             'name': 'Satan',
#                             'notifications': False,
#                             'profile_background_color': '000000',
#                             'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#                             'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#                             'profile_background_tile': False,
#                             'profile_banner_url': 'https://pbs.twimg.com/profile_banners/13615722/1455479554',
#                             'profile_image_url': 'http://pbs.twimg.com/profile_images/738139405446062081/x0FQk9Yl_normal.jpg',
#                             'profile_image_url_https': 'https://pbs.twimg.com/profile_images/738139405446062081/x0FQk9Yl_normal.jpg',
#                             'profile_link_color': 'FF0000',
#                             'profile_sidebar_border_color': '000000',
#                             'profile_sidebar_fill_color': 'DDEEF6',
#                             'profile_text_color': '333333',
#                             'profile_use_background_image': True,
#                             'protected': False,
#                             'screen_name': 's8n',
#                             'statuses_count': 2664,
#                             'time_zone': None,
#                             'translator_type': 'none',
#                             'url': 'https://t.co/SApjh0eykv',
#                             'utc_offset': None,
#                             'verified': False}},
#  'quoted_status_id': 1083439025065742341,
#  'quoted_status_id_str': '1083439025065742341',
#  'retweet_count': 992,
#  'retweeted': False,
#  'source': '<a href="http://twitter.com/download/iphone" '
#            'rel="nofollow">Twitter for iPhone</a>',
#  'truncated': False,
#  'user': {'contributors_enabled': False,
#           'created_at': 'Thu Apr 02 21:09:40 +0000 2009',
#           'default_profile': False,
#           'default_profile_image': False,
#           'description': 'ICE T Leader of BODYCOUNT & The FINAL LEVEL TWITTER '
#                          "GANG. #FLTG @ICEMFT on INSTAGRAM BodyCount's new "
#                          "album BLOODLUST is out NOW!!'",
#           'entities': {'description': {'urls': []}},
#           'favourites_count': 184887,
#           'follow_request_sent': False,
#           'followers_count': 1095109,
#           'following': False,
#           'friends_count': 1418,
#           'geo_enabled': True,
#           'has_extended_profile': False,
#           'id': 28420827,
#           'id_str': '28420827',
#           'is_translation_enabled': False,
#           'is_translator': False,
#           'lang': 'en',
#           'listed_count': 6484,
#           'location': 'THE HOOD',
#           'name': 'ICE T',
#           'notifications': False,
#           'profile_background_color': '9AE4E8',
#           'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#           'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#           'profile_background_tile': True,
#           'profile_banner_url': 'https://pbs.twimg.com/profile_banners/28420827/1529487640',
#           'profile_image_url': 'http://pbs.twimg.com/profile_images/909984858818170881/jagXDTlf_normal.jpg',
#           'profile_image_url_https': 'https://pbs.twimg.com/profile_images/909984858818170881/jagXDTlf_normal.jpg',
#           'profile_link_color': '0084B4',
#           'profile_sidebar_border_color': 'FFFFFF',
#           'profile_sidebar_fill_color': 'DDFFCC',
#           'profile_text_color': '333333',
#           'profile_use_background_image': True,
#           'protected': False,
#           'screen_name': 'FINALLEVEL',
#           'statuses_count': 29386,
#           'time_zone': None,
#           'translator_type': 'none',
#           'url': None,
#           'utc_offset': None,
#           'verified': True}}
# --------------------------------------------------------
# {'contributors': None,
#  'coordinates': None,
#  'created_at': 'Thu Jan 10 07:57:35 +0000 2019',
#  'display_text_range': [0, 12],
#  'entities': {'hashtags': [],
#               'symbols': [],
#               'urls': [{'display_url': 'twitter.com/s8n/status/108…',
#                         'expanded_url': 'https://twitter.com/s8n/status/1083026459973898240',
#                         'indices': [13, 36],
#                         'url': 'https://t.co/Nht4B3qjax'}],
#               'user_mentions': []},
#  'favorite_count': 4414,
#  'favorited': False,
#  'full_text': 'thanks Satan https://t.co/Nht4B3qjax',
#  'geo': None,
#  'id': 1083271622746955776,
#  'id_str': '1083271622746955776',
#  'in_reply_to_screen_name': None,
#  'in_reply_to_status_id': None,
#  'in_reply_to_status_id_str': None,
#  'in_reply_to_user_id': None,
#  'in_reply_to_user_id_str': None,
#  'is_quote_status': True,
#  'lang': 'en',
#  'metadata': {'iso_language_code': 'en', 'result_type': 'popular'},
#  'place': None,
#  'possibly_sensitive': True,
#  'quoted_status': {'contributors': None,
#                    'coordinates': None,
#                    'created_at': 'Wed Jan 09 15:43:24 +0000 2019',
#                    'display_text_range': [0, 60],
#                    'entities': {'hashtags': [],
#                                 'symbols': [],
#                                 'urls': [],
#                                 'user_mentions': []},
#                    'favorite_count': 120082,
#                    'favorited': False,
#                    'full_text': 'Suicide is never the answer. You gotta '
#                                 'outlive your enemies.',
#                    'geo': None,
#                    'id': 1083026459973898240,
#                    'id_str': '1083026459973898240',
#                    'in_reply_to_screen_name': None,
#                    'in_reply_to_status_id': None,
#                    'in_reply_to_status_id_str': None,
#                    'in_reply_to_user_id': None,
#                    'in_reply_to_user_id_str': None,
#                    'is_quote_status': False,
#                    'lang': 'en',
#                    'metadata': {'iso_language_code': 'en',
#                                 'result_type': 'popular'},
#                    'place': None,
#                    'retweet_count': 37471,
#                    'retweeted': False,
#                    'source': '<a href="http://twitter.com/download/iphone" '
#                              'rel="nofollow">Twitter for iPhone</a>',
#                    'truncated': False,
#                    'user': {'contributors_enabled': False,
#                             'created_at': 'Mon Feb 18 09:16:57 +0000 2008',
#                             'default_profile': False,
#                             'default_profile_image': False,
#                             'description': 'Not evil just misunderstood | '
#                                            'https://t.co/hmJcQBAXGh | '
#                                            'https://t.co/nruh9nGktk | '
#                                            'Snapchat: satans | Spam Acc: '
#                                            '@s8nspam',
#                             'entities': {'description': {'urls': [{'display_url': 'Instagram.com/s8n',
#                                                                    'expanded_url': 'http://Instagram.com/s8n',
#                                                                    'indices': [30,
#                                                                                53],
#                                                                    'url': 'https://t.co/hmJcQBAXGh'},
#                                                                   {'display_url': 's8n.tumblr.com',
#                                                                    'expanded_url': 'http://s8n.tumblr.com',
#                                                                    'indices': [56,
#                                                                                79],
#                                                                    'url': 'https://t.co/nruh9nGktk'}]},
#                                          'url': {'urls': [{'display_url': 's8n.co',
#                                                            'expanded_url': 'http://s8n.co',
#                                                            'indices': [0, 23],
#                                                            'url': 'https://t.co/SApjh0eykv'}]}},
#                             'favourites_count': 13206,
#                             'follow_request_sent': False,
#                             'followers_count': 764680,
#                             'following': False,
#                             'friends_count': 51,
#                             'geo_enabled': False,
#                             'has_extended_profile': True,
#                             'id': 13615722,
#                             'id_str': '13615722',
#                             'is_translation_enabled': False,
#                             'is_translator': False,
#                             'lang': 'en',
#                             'listed_count': 1696,
#                             'location': 'hell',
#                             'name': 'Satan',
#                             'notifications': False,
#                             'profile_background_color': '000000',
#                             'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#                             'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#                             'profile_background_tile': False,
#                             'profile_banner_url': 'https://pbs.twimg.com/profile_banners/13615722/1455479554',
#                             'profile_image_url': 'http://pbs.twimg.com/profile_images/738139405446062081/x0FQk9Yl_normal.jpg',
#                             'profile_image_url_https': 'https://pbs.twimg.com/profile_images/738139405446062081/x0FQk9Yl_normal.jpg',
#                             'profile_link_color': 'FF0000',
#                             'profile_sidebar_border_color': '000000',
#                             'profile_sidebar_fill_color': 'DDEEF6',
#                             'profile_text_color': '333333',
#                             'profile_use_background_image': True,
#                             'protected': False,
#                             'screen_name': 's8n',
#                             'statuses_count': 2664,
#                             'time_zone': None,
#                             'translator_type': 'none',
#                             'url': 'https://t.co/SApjh0eykv',
#                             'utc_offset': None,
#                             'verified': False}},
#  'quoted_status_id': 1083026459973898240,
#  'quoted_status_id_str': '1083026459973898240',
#  'retweet_count': 1075,
#  'retweeted': False,
#  'source': '<a href="http://twitter.com/download/iphone" '
#            'rel="nofollow">Twitter for iPhone</a>',
#  'truncated': False,
#  'user': {'contributors_enabled': False,
#           'created_at': 'Wed Aug 10 05:38:19 +0000 2011',
#           'default_profile': False,
#           'default_profile_image': False,
#           'description': 'working on an album. https://t.co/uELl4NGOOV',
#           'entities': {'description': {'urls': [{'display_url': 'pouya305.com',
#                                                  'expanded_url': 'http://www.pouya305.com',
#                                                  'indices': [21, 44],
#                                                  'url': 'https://t.co/uELl4NGOOV'}]}},
#           'favourites_count': 161546,
#           'follow_request_sent': False,
#           'followers_count': 296780,
#           'following': False,
#           'friends_count': 1991,
#           'geo_enabled': True,
#           'has_extended_profile': False,
#           'id': 352129069,
#           'id_str': '352129069',
#           'is_translation_enabled': True,
#           'is_translator': False,
#           'lang': 'en',
#           'listed_count': 1148,
#           'location': 'Miami Dade County',
#           'name': 'POUYA',
#           'notifications': False,
#           'profile_background_color': 'C0DEED',
#           'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#           'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#           'profile_background_tile': False,
#           'profile_banner_url': 'https://pbs.twimg.com/profile_banners/352129069/1545369492',
#           'profile_image_url': 'http://pbs.twimg.com/profile_images/1068253636399108098/-cpc8Gcl_normal.jpg',
#           'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1068253636399108098/-cpc8Gcl_normal.jpg',
#           'profile_link_color': '0084B4',
#           'profile_sidebar_border_color': 'FFFFFF',
#           'profile_sidebar_fill_color': 'DDEEF6',
#           'profile_text_color': '333333',
#           'profile_use_background_image': True,
#           'protected': False,
#           'screen_name': 'Pouyalilpou',
#           'statuses_count': 93665,
#           'time_zone': None,
#           'translator_type': 'none',
#           'url': None,
#           'utc_offset': None,
#           'verified': True}}
# --------------------------------------------------------
# {'contributors': None,
#  'coordinates': None,
#  'created_at': 'Fri Jan 11 22:39:21 +0000 2019',
#  'display_text_range': [5, 16],
#  'entities': {'hashtags': [],
#               'symbols': [],
#               'urls': [],
#               'user_mentions': [{'id': 13615722,
#                                  'id_str': '13615722',
#                                  'indices': [0, 4],
#                                  'name': 'Satan',
#                                  'screen_name': 's8n'}]},
#  'favorite_count': 10115,
#  'favorited': False,
#  'full_text': '@s8n Which head?',
#  'geo': None,
#  'id': 1083855912434102273,
#  'id_str': '1083855912434102273',
#  'in_reply_to_screen_name': 's8n',
#  'in_reply_to_status_id': 1083854910754603008,
#  'in_reply_to_status_id_str': '1083854910754603008',
#  'in_reply_to_user_id': 13615722,
#  'in_reply_to_user_id_str': '13615722',
#  'is_quote_status': False,
#  'lang': 'en',
#  'metadata': {'iso_language_code': 'en', 'result_type': 'popular'},
#  'place': None,
#  'retweet_count': 229,
#  'retweeted': False,
#  'source': '<a href="http://twitter.com" rel="nofollow">Twitter Web Client</a>',
#  'truncated': False,
#  'user': {'contributors_enabled': False,
#           'created_at': 'Sat Sep 26 22:56:04 +0000 2009',
#           'default_profile': False,
#           'default_profile_image': False,
#           'description': 'PMA!',
#           'entities': {'description': {'urls': []},
#                        'url': {'urls': [{'display_url': 'Cloakbrand.com',
#                                          'expanded_url': 'http://Cloakbrand.com',
#                                          'indices': [0, 23],
#                                          'url': 'https://t.co/4gvuciEEpq'}]}},
#           'favourites_count': 38355,
#           'follow_request_sent': False,
#           'followers_count': 4951714,
#           'following': False,
#           'friends_count': 418,
#           'geo_enabled': False,
#           'has_extended_profile': True,
#           'id': 77596200,
#           'id_str': '77596200',
#           'is_translation_enabled': False,
#           'is_translator': False,
#           'lang': 'en',
#           'listed_count': 4401,
#           'location': '',
#           'name': 'Jacksepticeye',
#           'notifications': False,
#           'profile_background_color': '000000',
#           'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#           'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#           'profile_background_tile': False,
#           'profile_banner_url': 'https://pbs.twimg.com/profile_banners/77596200/1545348892',
#           'profile_image_url': 'http://pbs.twimg.com/profile_images/1028443373219135488/PmY__KRS_normal.jpg',
#           'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1028443373219135488/PmY__KRS_normal.jpg',
#           'profile_link_color': '94D487',
#           'profile_sidebar_border_color': '000000',
#           'profile_sidebar_fill_color': '000000',
#           'profile_text_color': '000000',
#           'profile_use_background_image': False,
#           'protected': False,
#           'screen_name': 'Jack_Septic_Eye',
#           'statuses_count': 8785,
#           'time_zone': None,
#           'translator_type': 'regular',
#           'url': 'https://t.co/4gvuciEEpq',
#           'utc_offset': None,
#           'verified': True}}
# --------------------------------------------------------
# {'contributors': None,
#  'coordinates': None,
#  'created_at': 'Tue Jan 08 18:59:13 +0000 2019',
#  'display_text_range': [5, 29],
#  'entities': {'hashtags': [],
#               'symbols': [],
#               'urls': [],
#               'user_mentions': [{'id': 13615722,
#                                  'id_str': '13615722',
#                                  'indices': [0, 4],
#                                  'name': 'Satan',
#                                  'screen_name': 's8n'}]},
#  'favorite_count': 629,
#  'favorited': False,
#  'full_text': '@s8n Hey satan how’s it going',
#  'geo': None,
#  'id': 1082713352298786816,
#  'id_str': '1082713352298786816',
#  'in_reply_to_screen_name': 's8n',
#  'in_reply_to_status_id': 1082706023184510981,
#  'in_reply_to_status_id_str': '1082706023184510981',
#  'in_reply_to_user_id': 13615722,
#  'in_reply_to_user_id_str': '13615722',
#  'is_quote_status': False,
#  'lang': 'en',
#  'metadata': {'iso_language_code': 'en', 'result_type': 'popular'},
#  'place': None,
#  'retweet_count': 70,
#  'retweeted': False,
#  'source': '<a href="http://twitter.com/download/iphone" '
#            'rel="nofollow">Twitter for iPhone</a>',
#  'truncated': False,
#  'user': {'contributors_enabled': False,
#           'created_at': 'Mon Nov 02 18:03:52 +0000 2009',
#           'default_profile': False,
#           'default_profile_image': False,
#           'description': 'We make delicious MoonPies for everyone to enjoy '
#                          'even you',
#           'entities': {'description': {'urls': []},
#                        'url': {'urls': [{'display_url': 'moonpie.com',
#                                          'expanded_url': 'http://moonpie.com',
#                                          'indices': [0, 23],
#                                          'url': 'https://t.co/sVOVTTZ4Zu'}]}},
#           'favourites_count': 11017,
#           'follow_request_sent': False,
#           'followers_count': 272222,
#           'following': False,
#           'friends_count': 28,
#           'geo_enabled': True,
#           'has_extended_profile': False,
#           'id': 86993064,
#           'id_str': '86993064',
#           'is_translation_enabled': False,
#           'is_translator': False,
#           'lang': 'en',
#           'listed_count': 843,
#           'location': 'Chattanooga, TN',
#           'name': 'MoonPie',
#           'notifications': False,
#           'profile_background_color': '9AE4E8',
#           'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#           'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#           'profile_background_tile': False,
#           'profile_banner_url': 'https://pbs.twimg.com/profile_banners/86993064/1515010206',
#           'profile_image_url': 'http://pbs.twimg.com/profile_images/980968675313442823/s-bzE8-a_normal.jpg',
#           'profile_image_url_https': 'https://pbs.twimg.com/profile_images/980968675313442823/s-bzE8-a_normal.jpg',
#           'profile_link_color': '0084B4',
#           'profile_sidebar_border_color': 'BDDCAD',
#           'profile_sidebar_fill_color': 'DDFFCC',
#           'profile_text_color': '333333',
#           'profile_use_background_image': True,
#           'protected': False,
#           'screen_name': 'MoonPie',
#           'statuses_count': 11150,
#           'time_zone': None,
#           'translator_type': 'none',
#           'url': 'https://t.co/sVOVTTZ4Zu',
#           'utc_offset': None,
#           'verified': True}}
# --------------------------------------------------------
# {'contributors': None,
#  'coordinates': None,
#  'created_at': 'Fri Jan 11 19:08:00 +0000 2019',
#  'display_text_range': [0, 113],
#  'entities': {'hashtags': [],
#               'symbols': [],
#               'urls': [{'display_url': 'globalnews.ca/news/4837448/c…',
#                         'expanded_url': 'https://globalnews.ca/news/4837448/chris-pratt-daniel-fast-bible-diet/',
#                         'indices': [90, 113],
#                         'url': 'https://t.co/4RyZpeevRt'}],
#               'user_mentions': [{'id': 13615722,
#                                  'id_str': '13615722',
#                                  'indices': [70, 74],
#                                  'name': 'Satan',
#                                  'screen_name': 's8n'},
#                                 {'id': 204832963,
#                                  'id_str': '204832963',
#                                  'indices': [75, 89],
#                                  'name': 'God',
#                                  'screen_name': 'TheTweetOfGod'}]},
#  'favorite_count': 414,
#  'favorited': False,
#  'full_text': 'Oh Jesus. Chris Pratt is embarking on 21-day Bible-inspired '
#               'diet\n'
#               '\n'
#               'CC: @s8n @TheTweetOfGod https://t.co/4RyZpeevRt',
#  'geo': None,
#  'id': 1083802723785551873,
#  'id_str': '1083802723785551873',
#  'in_reply_to_screen_name': None,
#  'in_reply_to_status_id': None,
#  'in_reply_to_status_id_str': None,
#  'in_reply_to_user_id': None,
#  'in_reply_to_user_id_str': None,
#  'is_quote_status': False,
#  'lang': 'en',
#  'metadata': {'iso_language_code': 'en', 'result_type': 'popular'},
#  'place': {'attributes': {},
#            'bounding_box': {'coordinates': [[[-79.639319, 43.403221],
#                                              [-78.90582, 43.403221],
#                                              [-78.90582, 43.855401],
#                                              [-79.639319, 43.855401]]],
#                             'type': 'Polygon'},
#            'contained_within': [],
#            'country': 'Canada',
#            'country_code': 'CA',
#            'full_name': 'Toronto, Ontario',
#            'id': '3797791ff9c0e4c6',
#            'name': 'Toronto',
#            'place_type': 'city',
#            'url': 'https://api.twitter.com/1.1/geo/id/3797791ff9c0e4c6.json'},
#  'possibly_sensitive': False,
#  'retweet_count': 16,
#  'retweeted': False,
#  'source': '<a href="http://twitter.com" rel="nofollow">Twitter Web Client</a>',
#  'truncated': False,
#  'user': {'contributors_enabled': False,
#           'created_at': 'Thu Sep 15 20:45:48 +0000 2011',
#           'default_profile': False,
#           'default_profile_image': False,
#           'description': 'Social Media Editor @GlobalNews | Formerly @JSource '
#                          '| https://t.co/P2sJEOI5uI📸https://t.co/zNeZRJaUIm📸 '
#                          'https://t.co/a7nDieHJNR📸',
#           'entities': {'description': {'urls': [{'display_url': 'Instagram.com/ericmarkdo',
#                                                  'expanded_url': 'http://Instagram.com/ericmarkdo',
#                                                  'indices': [54, 77],
#                                                  'url': 'https://t.co/P2sJEOI5uI'},
#                                                 {'display_url': 'Instagram.com/way2ill_',
#                                                  'expanded_url': 'http://Instagram.com/way2ill_',
#                                                  'indices': [78, 101],
#                                                  'url': 'https://t.co/zNeZRJaUIm'},
#                                                 {'display_url': 'Instagram.com/portraitpage',
#                                                  'expanded_url': 'http://Instagram.com/portraitpage',
#                                                  'indices': [103, 126],
#                                                  'url': 'https://t.co/a7nDieHJNR'}]},
#                        'url': {'urls': [{'display_url': 'ericmarkdo.co',
#                                          'expanded_url': 'http://ericmarkdo.co',
#                                          'indices': [0, 23],
#                                          'url': 'https://t.co/ibZqwClGmn'}]}},
#           'favourites_count': 7279,
#           'follow_request_sent': False,
#           'followers_count': 1578,
#           'following': False,
#           'friends_count': 913,
#           'geo_enabled': True,
#           'has_extended_profile': True,
#           'id': 374170691,
#           'id_str': '374170691',
#           'is_translation_enabled': False,
#           'is_translator': False,
#           'lang': 'en',
#           'listed_count': 188,
#           'location': 'Toronto, Ontario',
#           'name': 'Eric Mark Do',
#           'notifications': False,
#           'profile_background_color': '000000',
#           'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme15/bg.png',
#           'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme15/bg.png',
#           'profile_background_tile': False,
#           'profile_banner_url': 'https://pbs.twimg.com/profile_banners/374170691/1402361205',
#           'profile_image_url': 'http://pbs.twimg.com/profile_images/877609240562733058/N3PYp5t__normal.jpg',
#           'profile_image_url_https': 'https://pbs.twimg.com/profile_images/877609240562733058/N3PYp5t__normal.jpg',
#           'profile_link_color': '066175',
#           'profile_sidebar_border_color': 'A9CBD9',
#           'profile_sidebar_fill_color': 'A9CBD9',
#           'profile_text_color': '000000',
#           'profile_use_background_image': True,
#           'protected': False,
#           'screen_name': 'EricMarkDo',
#           'statuses_count': 14843,
#           'time_zone': None,
#           'translator_type': 'regular',
#           'url': 'https://t.co/ibZqwClGmn',
#           'utc_offset': None,
#           'verified': True}}
# --------------------------------------------------------
# {'contributors': None,
#  'coordinates': None,
#  'created_at': 'Tue Jan 08 19:10:04 +0000 2019',
#  'display_text_range': [14, 58],
#  'entities': {'hashtags': [],
#               'symbols': [],
#               'urls': [],
#               'user_mentions': [{'id': 13615722,
#                                  'id_str': '13615722',
#                                  'indices': [0, 4],
#                                  'name': 'Satan',
#                                  'screen_name': 's8n'},
#                                 {'id': 783214,
#                                  'id_str': '783214',
#                                  'indices': [5, 13],
#                                  'name': 'Twitter',
#                                  'screen_name': 'Twitter'}]},
#  'favorite_count': 2006,
#  'favorited': False,
#  'full_text': '@s8n @Twitter In their defense you are literally the devil',
#  'geo': None,
#  'id': 1082716082996015104,
#  'id_str': '1082716082996015104',
#  'in_reply_to_screen_name': 's8n',
#  'in_reply_to_status_id': 1082714079519801345,
#  'in_reply_to_status_id_str': '1082714079519801345',
#  'in_reply_to_user_id': 13615722,
#  'in_reply_to_user_id_str': '13615722',
#  'is_quote_status': False,
#  'lang': 'en',
#  'metadata': {'iso_language_code': 'en', 'result_type': 'popular'},
#  'place': None,
#  'retweet_count': 41,
#  'retweeted': False,
#  'source': '<a href="http://twitter.com/download/iphone" '
#            'rel="nofollow">Twitter for iPhone</a>',
#  'truncated': False,
#  'user': {'contributors_enabled': False,
#           'created_at': 'Thu Aug 02 02:17:54 +0000 2012',
#           'default_profile': False,
#           'default_profile_image': False,
#           'description': 'The Best Wrapper Alive. As seen on Shark Tank. '
#                          '@DUDEproducts',
#           'entities': {'description': {'urls': []},
#                        'url': {'urls': [{'display_url': 'DUDEPRODUCTS.COM',
#                                          'expanded_url': 'http://WWW.DUDEPRODUCTS.COM',
#                                          'indices': [0, 23],
#                                          'url': 'https://t.co/tv2JC91j2T'}]}},
#           'favourites_count': 1594,
#           'follow_request_sent': False,
#           'followers_count': 4147,
#           'following': False,
#           'friends_count': 308,
#           'geo_enabled': True,
#           'has_extended_profile': False,
#           'id': 731953544,
#           'id_str': '731953544',
#           'is_translation_enabled': False,
#           'is_translator': False,
#           'lang': 'en',
#           'listed_count': 21,
#           'location': 'Pockets Worldwide',
#           'name': 'DUDE Wipes',
#           'notifications': False,
#           'profile_background_color': '131516',
#           'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme14/bg.gif',
#           'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme14/bg.gif',
#           'profile_background_tile': True,
#           'profile_banner_url': 'https://pbs.twimg.com/profile_banners/731953544/1497400815',
#           'profile_image_url': 'http://pbs.twimg.com/profile_images/828286528141012992/KZUp62YJ_normal.jpg',
#           'profile_image_url_https': 'https://pbs.twimg.com/profile_images/828286528141012992/KZUp62YJ_normal.jpg',
#           'profile_link_color': '009999',
#           'profile_sidebar_border_color': 'EEEEEE',
#           'profile_sidebar_fill_color': 'EFEFEF',
#           'profile_text_color': '333333',
#           'profile_use_background_image': True,
#           'protected': False,
#           'screen_name': 'DUDEwipes',
#           'statuses_count': 3232,
#           'time_zone': None,
#           'translator_type': 'none',
#           'url': 'https://t.co/tv2JC91j2T',
#           'utc_offset': None,
#           'verified': True}}
# --------------------------------------------------------
# {'contributors': None,
#  'coordinates': None,
#  'created_at': 'Thu Jan 10 01:08:53 +0000 2019',
#  'display_text_range': [5, 18],
#  'entities': {'hashtags': [],
#               'symbols': [],
#               'urls': [],
#               'user_mentions': [{'id': 13615722,
#                                  'id_str': '13615722',
#                                  'indices': [0, 4],
#                                  'name': 'Satan',
#                                  'screen_name': 's8n'}]},
#  'favorite_count': 2213,
#  'favorited': False,
#  'full_text': '@s8n Thanks, Satan',
#  'geo': None,
#  'id': 1083168768233156608,
#  'id_str': '1083168768233156608',
#  'in_reply_to_screen_name': 's8n',
#  'in_reply_to_status_id': 1083026459973898240,
#  'in_reply_to_status_id_str': '1083026459973898240',
#  'in_reply_to_user_id': 13615722,
#  'in_reply_to_user_id_str': '13615722',
#  'is_quote_status': False,
#  'lang': 'en',
#  'metadata': {'iso_language_code': 'en', 'result_type': 'popular'},
#  'place': None,
#  'retweet_count': 68,
#  'retweeted': False,
#  'source': '<a href="http://twitter.com/download/iphone" '
#            'rel="nofollow">Twitter for iPhone</a>',
#  'truncated': False,
#  'user': {'contributors_enabled': False,
#           'created_at': 'Wed Jan 08 01:32:27 +0000 2014',
#           'default_profile': False,
#           'default_profile_image': False,
#           'description': 'hey friends 👋',
#           'entities': {'description': {'urls': []},
#                        'url': {'urls': [{'display_url': 'youtube.com/c/akidearest',
#                                          'expanded_url': 'https://www.youtube.com/c/akidearest',
#                                          'indices': [0, 23],
#                                          'url': 'https://t.co/UdtKfYlg9r'}]}},
#           'favourites_count': 23515,
#           'follow_request_sent': False,
#           'followers_count': 243210,
#           'following': False,
#           'friends_count': 352,
#           'geo_enabled': True,
#           'has_extended_profile': True,
#           'id': 2281401692,
#           'id_str': '2281401692',
#           'is_translation_enabled': False,
#           'is_translator': False,
#           'lang': 'en',
#           'listed_count': 285,
#           'location': 'Las Vegas',
#           'name': 'Akidearest',
#           'notifications': False,
#           'profile_background_color': '000000',
#           'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#           'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#           'profile_background_tile': False,
#           'profile_banner_url': 'https://pbs.twimg.com/profile_banners/2281401692/1546500769',
#           'profile_image_url': 'http://pbs.twimg.com/profile_images/946975786241728512/Z5vQqGcQ_normal.jpg',
#           'profile_image_url_https': 'https://pbs.twimg.com/profile_images/946975786241728512/Z5vQqGcQ_normal.jpg',
#           'profile_link_color': 'ABB8C2',
#           'profile_sidebar_border_color': 'FFFFFF',
#           'profile_sidebar_fill_color': 'DDEEF6',
#           'profile_text_color': '333333',
#           'profile_use_background_image': True,
#           'protected': False,
#           'screen_name': 'akidearest',
#           'statuses_count': 304,
#           'time_zone': None,
#           'translator_type': 'none',
#           'url': 'https://t.co/UdtKfYlg9r',
#           'utc_offset': None,
#           'verified': True}}
# --------------------------------------------------------
# {'contributors': None,
#  'coordinates': None,
#  'created_at': 'Fri Jan 11 15:52:30 +0000 2019',
#  'display_text_range': [5, 58],
#  'entities': {'hashtags': [],
#               'symbols': [],
#               'urls': [],
#               'user_mentions': [{'id': 13615722,
#                                  'id_str': '13615722',
#                                  'indices': [0, 4],
#                                  'name': 'Satan',
#                                  'screen_name': 's8n'}]},
#  'favorite_count': 447,
#  'favorited': False,
#  'full_text': '@s8n I’m going to hell just for reading this, see ya soon.',
#  'geo': None,
#  'id': 1083753524335394817,
#  'id_str': '1083753524335394817',
#  'in_reply_to_screen_name': 's8n',
#  'in_reply_to_status_id': 1083753116732936192,
#  'in_reply_to_status_id_str': '1083753116732936192',
#  'in_reply_to_user_id': 13615722,
#  'in_reply_to_user_id_str': '13615722',
#  'is_quote_status': False,
#  'lang': 'en',
#  'metadata': {'iso_language_code': 'en', 'result_type': 'popular'},
#  'place': None,
#  'retweet_count': 16,
#  'retweeted': False,
#  'source': '<a href="http://twitter.com/download/iphone" '
#            'rel="nofollow">Twitter for iPhone</a>',
#  'truncated': False,
#  'user': {'contributors_enabled': False,
#           'created_at': 'Mon Aug 30 02:40:47 +0000 2010',
#           'default_profile': False,
#           'default_profile_image': False,
#           'description': 'Chief Community Officer at @GFUELEnergy  #GFUEL '
#                          '#Esports #Gaming',
#           'entities': {'description': {'urls': []},
#                        'url': {'urls': [{'display_url': 'GFUEL.COM',
#                                          'expanded_url': 'http://GFUEL.COM',
#                                          'indices': [0, 23],
#                                          'url': 'https://t.co/V6Uf5GbUFa'}]}},
#           'favourites_count': 35394,
#           'follow_request_sent': False,
#           'followers_count': 24692,
#           'following': False,
#           'friends_count': 2074,
#           'geo_enabled': True,
#           'has_extended_profile': True,
#           'id': 184637613,
#           'id_str': '184637613',
#           'is_translation_enabled': False,
#           'is_translator': False,
#           'lang': 'en',
#           'listed_count': 157,
#           'location': 'Orlando,FL ✈️ New York,NY',
#           'name': 'Scotty',
#           'notifications': False,
#           'profile_background_color': '000000',
#           'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme14/bg.gif',
#           'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme14/bg.gif',
#           'profile_background_tile': False,
#           'profile_banner_url': 'https://pbs.twimg.com/profile_banners/184637613/1545936725',
#           'profile_image_url': 'http://pbs.twimg.com/profile_images/1081190372016091136/0CZ2SZCn_normal.jpg',
#           'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1081190372016091136/0CZ2SZCn_normal.jpg',
#           'profile_link_color': '1B95E0',
#           'profile_sidebar_border_color': '000000',
#           'profile_sidebar_fill_color': '000000',
#           'profile_text_color': '000000',
#           'profile_use_background_image': False,
#           'protected': False,
#           'screen_name': 'ScottyTidwell',
#           'statuses_count': 92024,
#           'time_zone': None,
#           'translator_type': 'none',
#           'url': 'https://t.co/V6Uf5GbUFa',
#           'utc_offset': None,
#           'verified': True}}
# --------------------------------------------------------
# {'contributors': None,
#  'coordinates': None,
#  'created_at': 'Tue Jan 08 19:14:01 +0000 2019',
#  'display_text_range': [5, 42],
#  'entities': {'hashtags': [],
#               'symbols': [],
#               'urls': [],
#               'user_mentions': [{'id': 13615722,
#                                  'id_str': '13615722',
#                                  'indices': [0, 4],
#                                  'name': 'Satan',
#                                  'screen_name': 's8n'}]},
#  'favorite_count': 553,
#  'favorited': False,
#  'full_text': '@s8n I’m good do you still play the fiddle',
#  'geo': None,
#  'id': 1082717077729878016,
#  'id_str': '1082717077729878016',
#  'in_reply_to_screen_name': 's8n',
#  'in_reply_to_status_id': 1082714187221094400,
#  'in_reply_to_status_id_str': '1082714187221094400',
#  'in_reply_to_user_id': 13615722,
#  'in_reply_to_user_id_str': '13615722',
#  'is_quote_status': False,
#  'lang': 'en',
#  'metadata': {'iso_language_code': 'en', 'result_type': 'popular'},
#  'place': None,
#  'retweet_count': 20,
#  'retweeted': False,
#  'source': '<a href="http://twitter.com/download/iphone" '
#            'rel="nofollow">Twitter for iPhone</a>',
#  'truncated': False,
#  'user': {'contributors_enabled': False,
#           'created_at': 'Mon Nov 02 18:03:52 +0000 2009',
#           'default_profile': False,
#           'default_profile_image': False,
#           'description': 'We make delicious MoonPies for everyone to enjoy '
#                          'even you',
#           'entities': {'description': {'urls': []},
#                        'url': {'urls': [{'display_url': 'moonpie.com',
#                                          'expanded_url': 'http://moonpie.com',
#                                          'indices': [0, 23],
#                                          'url': 'https://t.co/sVOVTTZ4Zu'}]}},
#           'favourites_count': 11017,
#           'follow_request_sent': False,
#           'followers_count': 272222,
#           'following': False,
#           'friends_count': 28,
#           'geo_enabled': True,
#           'has_extended_profile': False,
#           'id': 86993064,
#           'id_str': '86993064',
#           'is_translation_enabled': False,
#           'is_translator': False,
#           'lang': 'en',
#           'listed_count': 843,
#           'location': 'Chattanooga, TN',
#           'name': 'MoonPie',
#           'notifications': False,
#           'profile_background_color': '9AE4E8',
#           'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#           'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#           'profile_background_tile': False,
#           'profile_banner_url': 'https://pbs.twimg.com/profile_banners/86993064/1515010206',
#           'profile_image_url': 'http://pbs.twimg.com/profile_images/980968675313442823/s-bzE8-a_normal.jpg',
#           'profile_image_url_https': 'https://pbs.twimg.com/profile_images/980968675313442823/s-bzE8-a_normal.jpg',
#           'profile_link_color': '0084B4',
#           'profile_sidebar_border_color': 'BDDCAD',
#           'profile_sidebar_fill_color': 'DDFFCC',
#           'profile_text_color': '333333',
#           'profile_use_background_image': True,
#           'protected': False,
#           'screen_name': 'MoonPie',
#           'statuses_count': 11150,
#           'time_zone': None,
#           'translator_type': 'none',
#           'url': 'https://t.co/sVOVTTZ4Zu',
#           'utc_offset': None,
#           'verified': True}}
# --------------------------------------------------------

# %%
#Save the Tweets
file_name = 'search_tweets.json'

# %%
# Iterate through search results and save the tweet
with open(file_name, 'w') as f:
    for tweet in search_results:
        f.write(jsonpickle.encode(tweet._json, unpicklable=False) +
                        '\n')

# %% [markdown]
# #### Streaming API

# %%
#override tweepy.StreamListener to add logic to on_status
class MyListener(StreamListener):
 
    def on_data(self, data):
        try:
            pprint(data)
            return True
        except BaseException as e:
            print("Error on_data: %s" % str(e))
        return True
 
    def on_error(self, status):
        pprint(status)
        return True

twitter_stream = Stream(auth, MyListener())
twitter_stream.filter(track=['OdishaStandsUpForFarmers'])
# Out:
# ---------------------------------------------------------------------------
# WantReadError                             Traceback (most recent call last)
# ~/anaconda3/lib/python3.6/site-packages/urllib3/contrib/pyopenssl.py in recv_into(self, *args, **kwargs)
#     279         try:
# --> 280             return self.connection.recv_into(*args, **kwargs)
#     281         except OpenSSL.SSL.SysCallError as e:
#
# ~/anaconda3/lib/python3.6/site-packages/OpenSSL/SSL.py in recv_into(self, buffer, nbytes, flags)
#    1813             result = _lib.SSL_read(self._ssl, buf, nbytes)
# -> 1814         self._raise_ssl_error(self._ssl, result)
#    1815
#
# ~/anaconda3/lib/python3.6/site-packages/OpenSSL/SSL.py in _raise_ssl_error(self, ssl, result)
#    1613         if error == _lib.SSL_ERROR_WANT_READ:
# -> 1614             raise WantReadError()
#    1615         elif error == _lib.SSL_ERROR_WANT_WRITE:
#
# WantReadError:
#
# During handling of the above exception, another exception occurred:
#
# timeout                                   Traceback (most recent call last)
# ~/anaconda3/lib/python3.6/site-packages/urllib3/response.py in _error_catcher(self)
#     301             try:
# --> 302                 yield
#     303
#
# ~/anaconda3/lib/python3.6/site-packages/urllib3/response.py in read(self, amt, decode_content, cache_content)
#     383                 cache_content = False
# --> 384                 data = self._fp.read(amt)
#     385                 if amt != 0 and not data:  # Platform-specific: Buggy versions of Python.
#
# ~/anaconda3/lib/python3.6/http/client.py in read(self, amt)
#     448             b = bytearray(amt)
# --> 449             n = self.readinto(b)
#     450             return memoryview(b)[:n].tobytes()
#
# ~/anaconda3/lib/python3.6/http/client.py in readinto(self, b)
#     482         if self.chunked:
# --> 483             return self._readinto_chunked(b)
#     484
#
# ~/anaconda3/lib/python3.6/http/client.py in _readinto_chunked(self, b)
#     587                 temp_mvb = mvb[:chunk_left]
# --> 588                 n = self._safe_readinto(temp_mvb)
#     589                 mvb = mvb[n:]
#
# ~/anaconda3/lib/python3.6/http/client.py in _safe_readinto(self, b)
#     627             else:
# --> 628                 n = self.fp.readinto(mvb)
#     629             if not n:
#
# ~/anaconda3/lib/python3.6/socket.py in readinto(self, b)
#     585             try:
# --> 586                 return self._sock.recv_into(b)
#     587             except timeout:
#
# ~/anaconda3/lib/python3.6/site-packages/urllib3/contrib/pyopenssl.py in recv_into(self, *args, **kwargs)
#     293             if not rd:
# --> 294                 raise timeout('The read operation timed out')
#     295             else:
#
# timeout: The read operation timed out
#
# During handling of the above exception, another exception occurred:
#
# ReadTimeoutError                          Traceback (most recent call last)
# <ipython-input-12-4be67937427c> in <module>()
#      15
#      16 twitter_stream = Stream(auth, MyListener())
# ---> 17 twitter_stream.filter(track=['OdishaStandsUpForFarmers'])
#
# ~/anaconda3/lib/python3.6/site-packages/tweepy/streaming.py in filter(self, follow, track, async, locations, stall_warnings, languages, encoding, filter_level)
#     443         self.session.params = {'delimited': 'length'}
#     444         self.host = 'stream.twitter.com'
# --> 445         self._start(async)
#     446
#     447     def sitestream(self, follow, stall_warnings=False,
#
# ~/anaconda3/lib/python3.6/site-packages/tweepy/streaming.py in _start(self, async)
#     359             self._thread.start()
#     360         else:
# --> 361             self._run()
#     362
#     363     def on_closed(self, resp):
#
# ~/anaconda3/lib/python3.6/site-packages/tweepy/streaming.py in _run(self)
#     292             # call a handler first so that the exception can be logged.
#     293             self.listener.on_exception(exception)
# --> 294             raise exception
#     295
#     296     def _data(self, data):
#
# ~/anaconda3/lib/python3.6/site-packages/tweepy/streaming.py in _run(self)
#     261                     self.snooze_time = self.snooze_time_step
#     262                     self.listener.on_connect()
# --> 263                     self._read_loop(resp)
#     264             except (Timeout, ssl.SSLError) as exc:
#     265                 # This is still necessary, as a SSLError can actually be
#
# ~/anaconda3/lib/python3.6/site-packages/tweepy/streaming.py in _read_loop(self, resp)
#     311             length = 0
#     312             while not resp.raw.closed:
# --> 313                 line = buf.read_line().strip()
#     314                 if not line:
#     315                     self.listener.keep_alive()  # keep-alive new lines are expected
#
# ~/anaconda3/lib/python3.6/site-packages/tweepy/streaming.py in read_line(self, sep)
#     177             else:
#     178                 start = len(self._buffer)
# --> 179             self._buffer += self._stream.read(self._chunk_size)
#     180
#     181     def _pop(self, length):
#
# ~/anaconda3/lib/python3.6/site-packages/urllib3/response.py in read(self, amt, decode_content, cache_content)
#     399                         # raised during streaming, so all calls with incorrect
#     400                         # Content-Length are caught.
# --> 401                         raise IncompleteRead(self._fp_bytes_read, self.length_remaining)
#     402
#     403         if data:
#
# ~/anaconda3/lib/python3.6/contextlib.py in __exit__(self, type, value, traceback)
#      97                 value = type()
#      98             try:
# ---> 99                 self.gen.throw(type, value, traceback)
#     100             except StopIteration as exc:
#     101                 # Suppress StopIteration *unless* it's the same exception that
#
# ~/anaconda3/lib/python3.6/site-packages/urllib3/response.py in _error_catcher(self)
#     305                 # FIXME: Ideally we'd like to include the url in the ReadTimeoutError but
#     306                 # there is yet no clean way to get at it from this context.
# --> 307                 raise ReadTimeoutError(self._pool, None, 'Read timed out.')
#     308
#     309             except BaseSSLError as e:
#
# ReadTimeoutError: HTTPSConnectionPool(host='stream.twitter.com', port=443): Read timed out.

# %% [markdown]
# # Part 3
#
# ## Analysing Twitter Data
#
# ### Fetch already collected Twitter data
# In order to do any kind of analysis, we should have large amount of data. So, we would use the dataset of tweets collected using #WorldCup and can be downloaded here. Once downloaded, move the JSON file to a folder named resource in the root of the project.
#
# The dataset contains a text file containing the Twitter API responses. The structure of the tweet is same as we've seen before.
#
# #### How do I fetch this data?
# > - Import the libraries and read the file
# > - Convert the tweet string to Python dictionary
