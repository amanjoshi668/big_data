# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import gmplot
import calendar
from IPython.display import HTML
import seaborn as sns

# %% [markdown]
# # Question 1
# #### Baltimore_crimes.csv

# %% [markdown]
# ### 1.1

# %%
data = pd.read_csv("baltimore_crimes.csv")
orig_data = data

# %%
display(data.columns.values)
# Out:
# array(['CrimeDate', 'CrimeTime', 'CrimeCode', 'Location', 'Description',
#        'Weapon', 'Post', 'District', 'Neighborhood', 'Location 1',
#        'Total Incidents'], dtype=object)

# %%
data['Location 1'] = [ list(map(float, s[2:-3].split(', '))) for s in data['Location 1']]
data['longitude'] = [ i[0] for i in data['Location 1']]
data['latitude'] = [i[1] for i in data['Location 1']]
data['Location 1'] = orig_data['Location 1']
data['Weapon'] = data['Weapon'].fillna('Not Available')

# %%
display(data.head())
display(data.describe())
# Out:
#     CrimeDate CrimeTime CrimeCode              Location        Description  \
# 0  09/01/2015  23:58:00        4C         600 S PACA ST       AGG. ASSAULT
# 1  09/01/2015  23:36:00        6J        1000 EVANS WAY            LARCENY
# 2  09/01/2015  23:30:00        4B          300 W CAMDEN       AGG. ASSAULT
# 3  09/01/2015  23:30:00        6D          1100 RACE ST  LARCENY FROM AUTO
# 4  09/01/2015  22:25:00        4E  1000 WASHINGTON BLVD     COMMON ASSAULT
#
#           Weapon   Post      District               Neighborhood  \
# 0          OTHER  941.0      SOUTHERN          Ridgely's Delight
# 1  Not Available  433.0  NORTHEASTERN          Armistead Gardens
# 2          KNIFE  941.0       CENTRAL               Stadium Area
# 3  Not Available  942.0      SOUTHERN           Sharp-Leadenhall
# 4  Not Available  932.0      SOUTHERN  Washington Village/Pigtow
#
#              Location 1  Total Incidents  longitude  latitude
# 0  [9.28301, -76.62475]                1    9.28301 -76.62475
# 1  [9.30486, -76.54518]                1    9.30486 -76.54518
# 2   [9.28523, -76.6197]                1    9.28523 -76.61970
# 3   [9.2761, -76.61671]                1    9.27610 -76.61671
# 4   [9.2829, -76.63189]                1    9.28290 -76.63189
#               Post  Total Incidents    longitude     latitude
# count  9640.000000           9641.0  9641.000000  9641.000000
# mean    500.333506              1.0     9.285599   -76.615281
# std     328.636056              0.0     0.016334     0.038580
# min     111.000000              1.0     9.215390   -76.711100
# 25%     213.000000              1.0     9.281520   -76.642960
# 50%     321.000000              1.0     9.289070   -76.614290
# 75%     841.000000              1.0     9.295990   -76.587560
# max     943.000000              1.0     9.305670   -76.529290

# %%
district, count = np.unique(data['District'], return_counts=True)
plt.style.use('fivethirtyeight')
plt.figure(figsize=(20,8))
plt.bar(district, count)
plt.xlabel('district')
plt.ylabel('count')
# Out:
# Text(0, 0.5, 'count')

# %% [markdown]
# ## Observations:
# - Southern Eastern district has most number of crimes
# - North Eastern district has least number of crimes

# %%
lat = [2,4]
long = [20,40]
gmap = gmplot.GoogleMapPlotter(data['latitude'].mean(), data['longitude'].mean(), 16)

# %%
gmap.heatmap(data['latitude'], data['longitude'])

# %%
gmap.draw('mymap.html')

# %%
from bs4 import BeautifulSoup
apikey = "AIzaSyD55jVeFKv2GHf6xaPK1vXTTjDlJiXgnl8"
def insertapikey(fname, apikey):
    """put the google api key in a html file"""
    def putkey(htmltxt, apikey, apistring=None):
        """put the apikey in the htmltxt and return soup"""
        if not apistring:
            apistring = "https://maps.googleapis.com/maps/api/js?key=%s&callback=initMap"
        soup = BeautifulSoup(htmltxt, 'html.parser')
        body = soup.body
        src = apistring % (apikey, )
        tscript = soup.new_tag("script", src=src, async="defer")
        body.insert(-1, tscript)
        return soup
    htmltxt = open(fname, 'r').read()
    soup = putkey(htmltxt, apikey)
    newtxt = soup.prettify()
    open(fname, 'w').write(newtxt)
apikey='AIzaSyBiefxu8a5svt6TiNmm8voJTCD2PY73j6U'
insertapikey("mymap.html", apikey)

# %%
display(HTML(filename='mymap.html'))
# Out:
# <html>
#  <head>
#   <meta content="initial-scale=1.0, user-scalable=no" name="viewport"/>
#   <meta content="text/html; charset=utf-8" http-equiv="content-type"/>
#   <title>
#    Google Maps - pygmaps
#   </title>
#   <script src="https://maps.googleapis.com/maps/api/js?libraries=visualization&amp;sensor=true_or_false" type="text/javascript">
#   </script>
#   <script type="text/javascript">
#    function initialize() {
# 		var centerlatlng = new google.maps.LatLng(-76.615281, 9.285599);
# 		var myOptions = {
# 			zoom: 16,
# 			center: centerlatlng,
# 			mapTypeId: google.maps.MapTypeId.ROADMAP
# 		};
# 		var map = new google.maps.Map(document.getElementById("map_canvas"), myOptions);
#
# var heatmap_points = [
# new google.maps.LatLng(-76.624750, 9.283010),
# new google.maps.LatLng(-76.545180, 9.304860),
# new google.maps.LatLng(-76.619700, 9.285230),
# new google.maps.LatLng(-76.616710, 9.276100),
# new google.maps.LatLng(-76.631890, 9.282900),
# new google.maps.LatLng(-76.639730, 9.289740),
# new google.maps.LatLng(-76.628280, 9.300540),
# new google.maps.LatLng(-76.566770, 9.278500),
# new google.maps.LatLng(-76.587000, 9.285520),
# new google.maps.LatLng(-76.665120, 9.275870),
# new google.maps.LatLng(-76.610420, 9.298830),
# new google.maps.LatLng(-76.643120, 9.301240),
# new google.maps.LatLng(-76.531140, 9.291270),
# new google.maps.LatLng(-76.644780, 9.281070),
# new google.maps.LatLng(-76.695790, 9.274500),
# new google.maps.LatLng(-76.623170, 9.283040),
# new google.maps.LatLng(-76.594280, 9.301110),
# new google.maps.LatLng(-76.571930, 9.280970),
# new google.maps.LatLng(-76.624360, 9.303760),
# new google.maps.LatLng(-76.675780, 9.288530),
# new google.maps.LatLng(-76.649410, 9.253890),
# new google.maps.LatLng(-76.613100, 9.271550),
# new google.maps.LatLng(-76.648870, 9.284190),
# new google.maps.LatLng(-76.563080, 9.286810),
# new google.maps.LatLng(-76.684740, 9.283270),
# new google.maps.LatLng(-76.670630, 9.303110),
# new google.maps.LatLng(-76.540480, 9.275320),
# new google.maps.LatLng(-76.585050, 9.297030),
# new google.maps.LatLng(-76.649050, 9.287030),
# new google.maps.LatLng(-76.642170, 9.284110),
# new google.maps.LatLng(-76.674820, 9.267920),
# new google.maps.LatLng(-76.575590, 9.294300),
# new google.maps.LatLng(-76.629550, 9.283860),
# new google.maps.LatLng(-76.613690, 9.288000),
# new google.maps.LatLng(-76.605300, 9.233610),
# new google.maps.LatLng(-76.611650, 9.270300),
# new google.maps.LatLng(-76.613290, 9.274410),
# new google.maps.LatLng(-76.573850, 9.277950),
# new google.maps.LatLng(-76.659390, 9.294620),
# new google.maps.LatLng(-76.615720, 9.280280),
# new google.maps.LatLng(-76.579340, 9.297890),
# new google.maps.LatLng(-76.613310, 9.273460),
# new google.maps.LatLng(-76.656250, 9.292830),
# new google.maps.LatLng(-76.656250, 9.292830),

# %%
days=["Monday","Tuesday","Wednesday","Thursday","Friday","Saturday","Sunday"]
sns.set_palette(sns.color_palette("hls", 15))
def day_of_week(day):
    month, day, year = (int(x) for x in day.split('/'))
    return calendar.weekday(year, month, day)
plt.figure(figsize=(20,8))
plt.semilogy()
for value in np.unique(data['Description']):
    crime_data  = data[data['Description'] == value].dropna()
    count = np.unique([day_of_week(date) for date in crime_data['CrimeDate']], return_counts=True)[-1]
    plt.plot(days, count, '-D',linewidth=1,label=value)
    plt.legend(bbox_to_anchor=(1.04,1), loc="upper left")
count = np.unique([day_of_week(date) for date in data['CrimeDate']], return_counts=True)[-1]
plt.plot(days, count, '-D',linewidth=1,label="TOTAL")
plt.legend(bbox_to_anchor=(1.04,1), loc="upper left")
plt.style.use('fivethirtyeight')
plt.ylabel("Frequency of Crime")
plt.xlabel("Days of week")
plt.show()

# %% [markdown]
# ## Observations:
# - Most crimes of week occur on tuesday.

# %%
data_hourly = data
data_hourly['Hour'] = [int(i.split(':')[0]) for i in data['CrimeTime']]
data_hourly = data_hourly[data_hourly['Hour']<24].dropna()
# display(np.unique(data['Hour'], return_counts=True))

# %%
def plot_by_time(data_hourly):
    sns.set_palette(sns.color_palette("hls", 15))
    plt.figure(figsize=(20,8))
    for value in np.unique(data_hourly['Description']):
        crime_data  = data_hourly[data_hourly['Description'] == value].dropna()
        time, count = np.unique(crime_data['Hour'], return_counts=True)
        plt.plot(time, count,'-D',linewidth=1, label=value)
        plt.plot()
        plt.legend(bbox_to_anchor=(1.04,1), loc="upper left")
    plt.style.use('fivethirtyeight')
    plt.ylabel("Frequency of Crime")
    plt.xlabel("Time of day")
    plt.show()

# %%
plot_by_time(data_hourly)

# %%
data_20_24 = data_hourly[data_hourly['Hour']>19].dropna()
plot_by_time(data_20_24)

# %% [markdown]
# ## Observations:
# - Larcey From Auto is the most common crime from 20:00 to 23:59
# - Larcey is the second most common crime from 20:00 to 23:59

# %%
value, count = np.unique(data['Description'], return_counts=True)
plt.style.use('fivethirtyeight')
plt.figure(figsize=(30,8))
plt.bar(value, count)
plt.xlabel('Crime type')
plt.ylabel('Frequency of crime')
# Out:
# Text(0, 0.5, 'Frequency of crime')

# %%
crime_data  = data_hourly[data_hourly['Description'] == 'LARCENY'].dropna()
time, count = np.unique(crime_data['Hour'], return_counts=True)
plt.style.use('fivethirtyeight')
plt.figure(figsize=(30,8))
plt.bar(time, count)
plt.xlabel('Crime type')
plt.ylabel('Frequency of crime')
# Out:
# Text(0, 0.5, 'Frequency of crime')

# %% [markdown]
# # Question 2

# %%
terrorism_data = pd.read_excel('global_terrorism_database.xlsx', sheet_name='Data')

# %%
terrorism_data.head()
# Out:
#         eventid  iyear  imonth  iday approxdate  extended resolution  country  \
# 0  197000000001   1970       7     2        NaN         0        NaT       58
# 1  197000000002   1970       0     0        NaN         0        NaT      130
# 2  197001000001   1970       1     0        NaN         0        NaT      160
# 3  197001000002   1970       1     0        NaN         0        NaT       78
# 4  197001000003   1970       1     0        NaN         0        NaT      101
#
#           country_txt  region  ... addnotes scite1 scite2  scite3  dbsource  \
# 0  Dominican Republic       2  ...      NaN    NaN    NaN     NaN      PGIS
# 1              Mexico       1  ...      NaN    NaN    NaN     NaN      PGIS
# 2         Philippines       5  ...      NaN    NaN    NaN     NaN      PGIS
# 3              Greece       8  ...      NaN    NaN    NaN     NaN      PGIS
# 4               Japan       4  ...      NaN    NaN    NaN     NaN      PGIS
#
#    INT_LOG  INT_IDEO INT_MISC INT_ANY  related
# 0        0         0        0       0      NaN
# 1        0         1        1       1      NaN
# 2       -9        -9        1       1      NaN
# 3       -9        -9        1       1      NaN
# 4       -9        -9        1       1      NaN
#
# [5 rows x 135 columns]

# %%
terrorism_data_NA = terrorism_data[terrorism_data['region_txt']=='North America'].dropna()
print(np.unique(terrorism_data_NA['iyear'], return_counts=True))
# Out:
# (array([], dtype=int64), array([], dtype=int64))

# %%
decade, count = np.unique(terrorism_data['iyear']/10, return_counts=True)
decade = np.array(decade,dtype=int)*10
plt.style.use('fivethirtyeight')
plt.figure(figsize=(20,8))
plt.bar(decade, count, width=5)
plt.xlabel('Year')
plt.ylabel('Frequency of crime')
# Out:
# Text(0, 0.5, 'Frequency of crime')

# %% [markdown]
# ## Observations
# - Decade 2010-2019 has most number of crimes

# %%
year, count = np.unique(terrorism_data['iyear'], return_counts=True)
plt.style.use('fivethirtyeight')
plt.figure(figsize=(30,8))
plt.bar(year, count, width=1)
plt.xlabel('Year')
plt.ylabel('Frequency of crime')
# Out:
# Text(0, 0.5, 'Frequency of crime')

# %% [markdown]
# ## Obseravation
# - Year 2014 has highest number of crime

# %%
terrorism_data_2014 = terrorism_data[terrorism_data['iyear']==2014].dropna() 
continent, count = np.unique(terrorism_data_2014['c'])

# %%
x = terrorism_data.columns
display(x[:40])
display(x[80:])
display(x[40:80])
# Out:
# Index(['eventid', 'iyear', 'imonth', 'iday', 'approxdate', 'extended',
#        'resolution', 'country', 'country_txt', 'region', 'region_txt',
#        'provstate', 'city', 'latitude', 'longitude', 'specificity', 'vicinity',
#        'location', 'summary', 'crit1', 'crit2', 'crit3', 'doubtterr',
#        'alternative', 'alternative_txt', 'multiple', 'success', 'suicide',
#        'attacktype1', 'attacktype1_txt', 'attacktype2', 'attacktype2_txt',
#        'attacktype3', 'attacktype3_txt', 'targtype1', 'targtype1_txt',
#        'targsubtype1', 'targsubtype1_txt', 'corp1', 'target1'],
#       dtype='object')
# Index(['compclaim', 'weaptype1', 'weaptype1_txt', 'weapsubtype1',
#        'weapsubtype1_txt', 'weaptype2', 'weaptype2_txt', 'weapsubtype2',
#        'weapsubtype2_txt', 'weaptype3', 'weaptype3_txt', 'weapsubtype3',
#        'weapsubtype3_txt', 'weaptype4', 'weaptype4_txt', 'weapsubtype4',
#        'weapsubtype4_txt', 'weapdetail', 'nkill', 'nkillus', 'nkillter',
#        'nwound', 'nwoundus', 'nwoundte', 'property', 'propextent',
#        'propextent_txt', 'propvalue', 'propcomment', 'ishostkid', 'nhostkid',
#        'nhostkidus', 'nhours', 'ndays', 'divert', 'kidhijcountry', 'ransom',
#        'ransomamt', 'ransomamtus', 'ransompaid', 'ransompaidus', 'ransomnote',
#        'hostkidoutcome', 'hostkidoutcome_txt', 'nreleased', 'addnotes',
#        'scite1', 'scite2', 'scite3', 'dbsource', 'INT_LOG', 'INT_IDEO',
#        'INT_MISC', 'INT_ANY', 'related'],
#       dtype='object')
# Index(['natlty1', 'natlty1_txt', 'targtype2', 'targtype2_txt', 'targsubtype2',
#        'targsubtype2_txt', 'corp2', 'target2', 'natlty2', 'natlty2_txt',
#        'targtype3', 'targtype3_txt', 'targsubtype3', 'targsubtype3_txt',
#        'corp3', 'target3', 'natlty3', 'natlty3_txt', 'gname', 'gsubname',
#        'gname2', 'gsubname2', 'gname3', 'gsubname3', 'motive', 'guncertain1',
#        'guncertain2', 'guncertain3', 'individual', 'nperps', 'nperpcap',
#        'claimed', 'claimmode', 'claimmode_txt', 'claim2', 'claimmode2',
#        'claimmode2_txt', 'claim3', 'claimmode3', 'claimmode3_txt'],
#       dtype='object')

# %%
print(np.unique(terrorism_data['region_txt'], return_counts=True))
# Out:
# (array(['Australasia & Oceania', 'Central America & Caribbean',
#        'Central Asia', 'East Asia', 'Eastern Europe',
#        'Middle East & North Africa', 'North America', 'South America',
#        'South Asia', 'Southeast Asia', 'Sub-Saharan Africa',
#        'Western Europe'], dtype=object), array([  282, 10344,   563,   802,  5144, 50474,  3456, 18978, 44974,
#        12485, 17550, 16639]))
