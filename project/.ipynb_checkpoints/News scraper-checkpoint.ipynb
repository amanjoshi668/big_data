# %%
import newspaper

# %%
nws = newspaper.build('https://timesofindia.indiatimes.com/')

# %%
from newspaper import Article

# %%
ar = Article(url="https://scroll.in/article/912867/human-trafficking-indias-border-with-myanmar-is-new-route-for-nepalese-people-being-taken-to-gulf")

# %%
ar.download()

# %%
ar.parse()

# %%
ar.tags
# Out:
# {'Human trafficking',
#  'India trafficking',
#  'Manipur',
#  'Myanmar',
#  'Neighbourhood Watch',
#  'Nepal',
#  'The Modi Years'}

# %%
txt = ar.text

# %%
txt
# Out:
# 'She had wanted to travel to Kuwait to find employment as a domestic worker. “Everyone used to go for work there and earn lots of money and send money to their families,” said the 33-year-old from Nepal’s Surkhet district. Her husband’s income as a marginal farmer was not enough to run the household and pay for the education of their four children, and there were few employment opportunities in Nepal for a school-dropout like her.\n\nTo counter human trafficking, the Nepalese authorities had clamped down on travel by Nepalis to West Asian countries, requiring them to submit extensive paperwork. But she was told by an agent that a new route to Kuwait had opened up – via India’s North East and Myanmar.\n\nShe did not make it to Kuwait. She could not even reach as far as Myanmar, from where she would have likely flown into Kuwait on a forged Myanmar passport. Instead, on February 1, she and 14 other Nepali nationals were intercepted by the Manipur police at the integrated check post in 
# ...

# %%
ar.nlp()

# %%
ar.keywords
# Out:
# ['trafficking',
#  'taken',
#  'border',
#  'moreh',
#  'manipur',
#  'nepalese',
#  'indias',
#  'gulf',
#  'myanmar',
#  'nepali',
#  'route',
#  'human',
#  'women']

# %%
import spacy 
nlp = spacy.load("en")

# %%
doc = nlp(txt)

# %%
from spacy import displacy
displacy.render(doc, style='ent', jupyter=True)
# Out:
# <div class="entities" style="line-height: 2.5">She had wanted to travel to
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     Kuwait
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#  to find employment as a domestic worker. “Everyone used to go for work there and earn lots of money and send money to their families,” said the 33-year-old from
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     Nepal
# ...

# %%
ent
# Out:
# Kuwait

# %%
dct = {
'PERSON':[],
'NORP':[],
'FAC':[],
'ORG':[],
'GPE':[],
'LOC':[],
'PRODUCT':[],
'EVENT':[],
'WORK_OF_ART':[],
'LAW':[],
'LANGUAGE':[],
'DATE':[],
'TIME':[],
'PERCENT':[],
'MONEY':[],
'QUANTITY':[],
'ORDINAL':[],
'CARDINAL':[]
    }

# %%
for ent in doc.ents:
    t,e = ent.text, ent.label_
    dct[e].append(t)

# %%
dct
# Out:
# {'PERSON': ['Nepalis',
#   'Manipuri',
#   'Bishwo Khadka',
#   'Khadka',
#   'Khadka',
#   'Nepalis',
#   'Colombo',
#   '\n\nKeisam Pradip Kumar',
#   'Hasina Kharbih',
#   'Kumar'],
#  'NORP': ['Nepalese',
#   'West Asian',
#   'Nepalese',
#   'Nepalese',
#   'Nepali',
#   'Nepalese',
#   'Indian',
#   'Nepalese',
#   'Nepalese',
#   'West Asian',
#   'Nepalese',
#   'Indian',
#   'Nepali',
#   'Nepalese',
#   'Sri Lankan',
#   'Burmese',
#   'Nepalese',
#   'Indian',
#   'Nepalese',
#   'Nepali',
#   'Nepali',
#   'Nepali',
#   'Asian',
#   'Nepali',
#   'Nepali'],
#  'FAC': ['the Trilateral Highway',
#   'Mandalay',
#   'the Indo-Nepal Friendship Treaty'],
#  'ORG': ['Nepali',
#   'Maiti Nepal',
#   'Controls',
#   'Sanjay Pradhan',
#   'Irrawaddy',
#   'the Manipur Commission for Protection of Child Rights',
#   'Manipuris',
#   'Assam Rifles',
#   'Assam Rifles',
#   'Assam Rifles',
#   'Customs',
#   'Migration'],
#  'GPE': ['Kuwait',
#   'Nepal',
#   'Surkhet',
#   'Nepal',
# ...

# %%
x=dct.items()

# %%
for token in doc:
    if token.tag_ == 'CD':
        print(token.text, token.head.text, token.head.head.text)
# Out:
# 33-year old said
# four children of
# 1 February on
# 14 nationals she
# one street town
# three countries connect
# three days within
# 1 February On
# 2 February February
# 179 people intercepted
# 147 women people
# 32 men women
# 33-year old including
# eight agents arrested
# one woman agents
# seven men woman
# 300 women crossed
# 131 crossed crossed
# 28 January on
# two vehicles “
# 27 women crossed
# 27 January on
# 1950 of Treaty
# 15 January as
# One detention spiral

# %%
dct
# Out:
# {'PERSON': ['Nepalis',
#   'Manipuri',
#   'Bishwo Khadka',
#   'Khadka',
#   'Khadka',
#   'Nepalis',
#   'Colombo',
#   '\n\nKeisam Pradip Kumar',
#   'Hasina Kharbih',
#   'Kumar'],
#  'NORP': ['Nepalese',
#   'West Asian',
#   'Nepalese',
#   'Nepalese',
#   'Nepali',
#   'Nepalese',
#   'Indian',
#   'Nepalese',
#   'Nepalese',
#   'West Asian',
#   'Nepalese',
#   'Indian',
#   'Nepali',
#   'Nepalese',
#   'Sri Lankan',
#   'Burmese',
#   'Nepalese',
#   'Indian',
#   'Nepalese',
#   'Nepali',
#   'Nepali',
#   'Nepali',
#   'Asian',
#   'Nepali',
#   'Nepali'],
#  'FAC': ['the Trilateral Highway',
#   'Mandalay',
#   'the Indo-Nepal Friendship Treaty'],
#  'ORG': ['Nepali',
#   'Maiti Nepal',
#   'Controls',
#   'Sanjay Pradhan',
#   'Irrawaddy',
#   'the Manipur Commission for Protection of Child Rights',
#   'Manipuris',
#   'Assam Rifles',
#   'Assam Rifles',
#   'Assam Rifles',
#   'Customs',
#   'Migration'],
#  'GPE': ['Kuwait',
#   'Nepal',
#   'Surkhet',
#   'Nepal',
# ...

# %%
countries involved, number of victims, gender, no.of accused, date
